# %%
import spacy

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import glob
import json

# %%
root_path = '../data/2020-03-13/'
metadata_path = f'{root_path}/all_sources_metadata_2020-03-13.csv'
meta_df = pd.read_csv(metadata_path, dtype={
    'pubmed_id': str,
    'Microsoft Academic Paper ID': str, 
    'doi': str
})
meta_df.head()
# Out:
#                                         sha source_x  \
# 0  c630ebcdf30652f0422c3ec12a00b50241dc9bd9      CZI
# 1  53eccda7977a31e3d0f565c884da036b1e85438e      CZI
# 2  210a892deb1c61577f6fba58505fd65356ce6636      CZI
# 3  e3b40cc8e0e137c416b4a2273a4dca94ae8178cc      CZI
# 4  92c2c9839304b4f2bc1276d41b1aa885d8b364fd      CZI
#
#                                                title  \
# 0  Angiotensin-converting enzyme 2 (ACE2) as a SA...
# 1  Comparative genetic analysis of the novel coro...
# 2  Incubation Period and Other Epidemiological Ch...
# 3  Characteristics of and Public Health Responses...
# 4       Imaging changes in severe COVID-19 pneumonia
#
#                           doi pmcid pubmed_id   license  \
# 0  10.1007/s00134-020-05985-9   NaN  32125455  cc-by-nc
# 1   10.1038/s41421-020-0147-1   NaN       NaN     cc-by
# 2          10.3390/jcm9020538   NaN       NaN     cc-by
# 3          10.3390/jcm9020575   NaN  32093211     cc-by
# 4  10.1007/s00134-020-05976-w   NaN  32125453  cc-by-nc
#
#                                             abstract publish_time  \
# 0                                                NaN         2020
# 1                                                NaN         2020
# 2  The geographic spread of 2019 novel coronaviru...         2020
# 3  In December 2019, cases of unidentified pneumo...         2020
# 4                                                NaN         2020
#
#                                              authors  \
# 0  Zhang, Haibo; Penninger, Josef M.; Li, Yimin; ...
# 1  Cao, Yanan; Li, Lin; Feng, Zhimin; Wan, Shengq...
# 2  Linton, M. Natalie; Kobayashi, Tetsuro; Yang, ...
# 3                   Deng, Sheng-Qun; Peng, Hong-Juan
# 4                                         Zhang, Wei
#
#                         journal Microsoft Academic Paper ID WHO #Covidence  \
# 0            Intensive Care Med                  2002765492          #3252
# 1                Cell Discovery                  3003430844          #1861
# 2  Journal of Clinical Medicine                  3006065484          #1043
# 3                    J Clin Med                   177663115          #1999
# 4            Intensive Care Med                  3006643024          #3242
#
#   has_full_text
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False

# %%
all_json = glob.glob(f'{root_path}/**/*.json', recursive=True)
# Out:
# 13202

# %%
class FileReader:
    def __init__(self, file_path):
        with open(file_path) as file:
            content = json.load(file)
            self.paper_id = content['paper_id']
            self.abstract = []
            self.body_text = []
            # Abstract
            for entry in content['abstract']:
                self.abstract.append(entry['text'])
            # Body text
            for entry in content['body_text']:
                self.body_text.append(entry['text'])
            self.abstract = '\n'.join(self.abstract)
            self.body_text = '\n'.join(self.body_text)
    def __repr__(self):
        return f'{self.paper_id}: {self.abstract[:200]}... {self.body_text[:200]}...'
first_row = FileReader(all_json[0])
print(first_row)
# Out:
# 8f8eb4f004c2002face0723f2f58cc411954d36e: Bordetella bronchiseptica isolate KM22 has been used in experimental infections of swine as a model of clinical B. bronchiseptica infection and to study host-to-host transmission. The draft genome seq... 20-kb insert library preparation protocol (https://www.pacb.com/wp-content/uploads/ Procedure-Checklist-20-kb-Template-Preparation-Using-BluePippin-Size-Selection -System.pdf). The 20-kb library was s...

# %%
def get_breaks(content, length):
    data = ""
    words = content.split(' ')
    total_chars = 0

    # add break every length characters
    for i in range(len(words)):
        total_chars += len(words[i])
        if total_chars > length:
            data = data + "<br>" + words[i]
            total_chars = 0
        else:
            data = data + " " + words[i]
    return data

# %%
dict_ = {'paper_id': [], 'abstract': [], 'body_text': [], 'authors': [], 'title': [], 'journal': [], 'abstract_summary': []}
for idx, entry in enumerate(all_json):
    if idx % (len(all_json) // 10) == 0:
        print(f'Processing index: {idx} of {len(all_json)}')
    content = FileReader(entry)
    
    # get metadata information
    meta_data = meta_df.loc[meta_df['sha'] == content.paper_id]
    # no metadata, skip this paper
    if len(meta_data) == 0:
        continue
    
    dict_['paper_id'].append(content.paper_id)
    dict_['abstract'].append(content.abstract)
    dict_['body_text'].append(content.body_text)
    
    # also create a column for the summary of abstract to be used in a plot
    if len(content.abstract) == 0: 
        # no abstract provided
        dict_['abstract_summary'].append("Not provided.")
    elif len(content.abstract.split(' ')) > 100:
        # abstract provided is too long for plot, take first 300 words append with ...
        info = content.abstract.split(' ')[:100]
        summary = get_breaks(' '.join(info), 40)
        dict_['abstract_summary'].append(summary + "...")
    else:
        # abstract is short enough
        summary = get_breaks(content.abstract, 40)
        dict_['abstract_summary'].append(summary)
        
    # get metadata information
    meta_data = meta_df.loc[meta_df['sha'] == content.paper_id]
    
    try:
        # if more than one author
        authors = meta_data['authors'].values[0].split(';')
        if len(authors) > 2:
            # more than 2 authors, may be problem when plotting, so take first 2 append with ...
            dict_['authors'].append(". ".join(authors[:2]) + "...")
        else:
            # authors will fit in plot
            dict_['authors'].append(". ".join(authors))
    except Exception as e:
        # if only one author - or Null valie
        dict_['authors'].append(meta_data['authors'].values[0])
    
    # add the title information, add breaks when needed
    try:
        title = get_breaks(meta_data['title'].values[0], 40)
        dict_['title'].append(title)
    # if title was not provided
    except Exception as e:
        dict_['title'].append(meta_data['title'].values[0])
    
    # add the journal information
    dict_['journal'].append(meta_data['journal'].values[0])
    
df_covid = pd.DataFrame(dict_, columns=['paper_id', 'abstract', 'body_text', 'authors', 'title', 'journal', 'abstract_summary'])
df_covid.head()
# Out:
# Processing index: 0 of 13202
# Processing index: 1320 of 13202
# Processing index: 2640 of 13202
# Processing index: 3960 of 13202
# Processing index: 5280 of 13202
# Processing index: 6600 of 13202
# Processing index: 7920 of 13202
# Processing index: 9240 of 13202
# Processing index: 10560 of 13202
# Processing index: 11880 of 13202
# Processing index: 13200 of 13202
#                                    paper_id  \
# 0  8f8eb4f004c2002face0723f2f58cc411954d36e
# 1  63f7049d200896290b38b38711113054f7ea1b50
# 2  4df45b8404d9de0b376a8ae3c282a517df36fe51
# 3  e0737ee93afe7b0bf06b1e3f9adf21d541dd10f0
# 4  3c3572ba243d61e7631725669c8f88347fdbd5bc
#
#                                             abstract  \
# 0  Bordetella bronchiseptica isolate KM22 has bee...
# 1
# 2  The influenza A nucleoprotein (NP) is an attra...
# 3  The outbreak of severe acute respiratory syndr...
# 4  The prevalence of feline herpesvirus-1 (FHV-1)...
#
#                                            body_text  \
# 0  20-kb insert library preparation protocol (htt...
# 1  I nfectious diseases have been an ever-present...
# 2  The transmission of a pathogenic avian H5N1 vi...
# 3  acute lung injury; inflammatory response; neut...
# 4  Feline herpesvirus type 1 (FHV-1) is the most ...
#
#                                              authors  \
# 0  ['Nicholson, Tracy L.', 'Bayles, Darrell O.', ...
# 1  ['Fauci, Anthony S.', 'Touchette, Nancy A.', '...
# 2  ['Cheung, Ying-Kit', 'Cheng, Samuel Chak-Sum',...
# 3  ['Han, Bing', 'Ma, Xuezhong', 'Zhang, Jianhua'...
# 4           ['Kang, Byeong-Teck', 'Park, Hee-Myung']
#
#                                                title  \
# 0   Complete Genome Sequence of Bordetella<br>bro...
# 1   Emerging Infectious Diseases: a 10-Year<br>Pe...
# 2   Two novel HLA-A*0201 T-cell epitopes in avian...
# 3   Protective Effects of Long Pentraxin PTX3 on<...
# 4   Prevalence of feline herpesvirus 1, feline<br...
#
#                     journal                                   abstract_summary
# 0  Microbiol Resour Announc   Bordetella bronchiseptica isolate KM22 has<br...
# 1          Emerg Infect Dis                                      Not provided.
# 2                   Vet Res   The influenza A nucleoprotein (NP) is an<br>a...
# 3                Lab Invest   The outbreak of severe acute respiratory<br>s...
# 4                 J Vet Sci   The prevalence of feline herpesvirus-1<br>(FH...

# %%
import spacy
nlp_vecs = spacy.load('en_core_sci_md')
nlp = spacy.load('en_ner_bc5cdr_md')

# %%
parsed_abstracts = [d for d in nlp.pipe(df_covid.abstract)]

# %%
# make an inventory of all entities
from collections import defaultdict
ent_count = defaultdict(int)
for d in parsed_abstracts:
    for e in d.ents:
        ent_count[(e.text, e.label_)]+=1
ent_inv = list(set([k[0] for k in ent_count]))
# max len
max_len = max([len(e.split()) for e in ent_inv])

# %%
# count of entities
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(vocabulary=ent_inv, ngram_range=(1, max_len))
ent_vecs = cv.fit_transform(df_covid.abstract)

# %%
#import gzip
#import pickle
#with gzip.open('parsed_abstracts.pkl.gz', 'wb') as f:
#    pickle.dump(parsed_abstracts, f)

# %%
# make an inventory of all entities
from collections import defaultdict
ent_count = defaultdict(int)
for d in parsed_abstracts:
    for e in d.ents:
        ent_count[(e.text, e.label_)]+=1

# %%
sorted(ent_count.items(), key=lambda x: x[1], reverse=True)
# Out:
# [(('infection', 'DISEASE'), 3607),
#  (('SARS', 'DISEASE'), 1264),
#  (('infections', 'DISEASE'), 892),
#  (('pneumonia', 'DISEASE'), 825),
#  (('diarrhea', 'DISEASE'), 746),
#  (('infectious diseases', 'DISEASE'), 711),
#  (('death', 'DISEASE'), 696),
#  (('MERS', 'DISEASE'), 586),
#  (('viral infection', 'DISEASE'), 568),
#  (('fever', 'DISEASE'), 515),
#  (('respiratory syndrome', 'DISEASE'), 487),
#  (('infectious disease', 'DISEASE'), 464),
#  (('cancer', 'DISEASE'), 454),
#  (('viral infections', 'DISEASE'), 447),
#  (('inflammation', 'DISEASE'), 439),
#  (('amino acid', 'CHEMICAL'), 434),
#  (('nucleotide', 'CHEMICAL'), 431),
#  (('tumor', 'DISEASE'), 387),
#  (('deaths', 'DISEASE'), 322),
#  (('acute respiratory syndrome', 'DISEASE'), 315),
#  (('NP', 'CHEMICAL'), 310),
#  (('TB', 'DISEASE'), 308),
#  (('virus infection', 'DISEASE'), 299),
#  (('ILI', 'DISEASE'), 291),
#  (('respiratory infections', 'DISEASE'), 288),
#  (('nucleic acid', 'CHEMICAL'), 266),
#  (('SARS-CoV-2', 'CHEMICAL'), 262),
#  (('ARI', 'DISEASE'), 250),
#  (('asthma', 'DISEASE'), 248),
#  (('ARDS', 'DISEASE'), 246),
#  (('CAP', 'CHEMICAL'), 244),
#  (('HA', 'CHEMICAL'), 235),
#  (('amino acids', 'CHEMICAL'), 230),
#  (('dengue', 'DISEASE'), 229),
#  (('FIP', 'DISEASE'), 225),
#  (('K', 'CHEMICAL'), 225),
#  (('cough', 'DISEASE'), 220),
#  (('respiratory disease', 'DISEASE'), 213),
#  (('malaria', 'DISEASE'), 210),
#  (('H1N1', 'DISEASE'), 204),
#  (('NF-κB', 'CHEMICAL'), 193),
#  (('respiratory tract infections', 'DISEASE'), 186),
#  (('IFN-γ', 'CHEMICAL'), 185),
#  (('oxygen', 'CHEMICAL'), 183),
#  (('NA', 'CHEMICAL'), 176),
#  (('CC', 'CHEMICAL'), 176),
#  (('MERS-CoV infection', 'DISEASE'), 175),
#  (('encephalitis', 'DISEASE'), 172),
#  (('TGEV', 'CHEMICAL'), 168),
#  (('enterovirus', 'DISEASE'), 157),
#  (('COPD', 'DISEASE'), 154),
#  (('sepsis', 'DISEASE'), 152),
#  (('SARI', 'DISEASE'), 152),
#  (('fibrosis', 'DISEASE'), 145),
#  (('hepatitis C', 'DISEASE'), 143),
#  (('respiratory syncytial virus', 'DISEASE'), 141),
#  (('respiratory infection', 'DISEASE'), 138),
#  (('COVID-19', 'DISEASE'), 136),
#  (('diarrhoea', 'DISEASE'), 134),
#  (('RSV infection', 'DISEASE'), 134),
#  (('PED', 'DISEASE'), 134),
#  (('respiratory illness', 'DISEASE'), 132),
#  (('LPS', 'CHEMICAL'), 132),
#  (('HFMD', 'DISEASE'), 130),
#  (('cholesterol', 'CHEMICAL'), 129),
#  (('Ca', 'CHEMICAL'), 128),
#  (('tuberculosis', 'DISEASE'), 122),
#  (('coronavirus', 'DISEASE'), 120),
#  (('nucleic acids', 'CHEMICAL'), 116),
#  (('ZIKV infection', 'DISEASE'), 116),
#  (('ARIs', 'DISEASE'), 115),
#  (('toxicity', 'DISEASE'), 115),
#  (('TNF-α', 'CHEMICAL'), 115),
#  (('PEDV infection', 'DISEASE'), 114),
#  (('Respiratory Syndrome', 'DISEASE'), 112),
#  (('throat', 'DISEASE'), 111),
#  (('NO', 'CHEMICAL'), 109),
#  (('E2', 'CHEMICAL'), 108),
#  (('hepatitis B', 'DISEASE'), 107),
#  (('TGEV', 'DISEASE'), 106),
#  (('febrile', 'DISEASE'), 104),
#  (('bronchitis', 'DISEASE'), 103),
#  (('HPV', 'DISEASE'), 103),
#  (('Infection', 'DISEASE'), 101),
#  (('ROS', 'CHEMICAL'), 100),
#  (('diabetes', 'DISEASE'), 99),
#  (('ALI', 'DISEASE'), 98),
#  (('demyelination', 'DISEASE'), 97),
#  (('bronchiolitis', 'DISEASE'), 96),
#  (('hepatitis', 'DISEASE'), 96),
#  (('ATP', 'CHEMICAL'), 96),
#  (('virus infections', 'DISEASE'), 93),
#  (('vomiting', 'DISEASE'), 92),
#  (('viral diseases', 'DISEASE'), 91),
#  (('respiratory tract infection', 'DISEASE'), 90),
#  (('influenza-like illness', 'DISEASE'), 89),
#  (('influenza infection', 'DISEASE'), 89),
#  (('IL-1β', 'CHEMICAL'), 88),
#  (('SNP', 'CHEMICAL'), 87),
#  (('tumors', 'DISEASE'), 86),
#  (('Streptococcus pneumoniae', 'DISEASE'), 86),
#  (('immunocompromised', 'DISEASE'), 85),
#  (('respiratory distress syndrome', 'DISEASE'), 84),
#  (('MERS-CoV.', 'CHEMICAL'), 83),
#  (('ribavirin', 'CHEMICAL'), 83),
#  (('sialic acid', 'CHEMICAL'), 83),
#  (('HCV infection', 'DISEASE'), 83),
#  (('weight loss', 'DISEASE'), 82),
#  (('IL-4', 'CHEMICAL'), 81),
#  (('AD', 'DISEASE'), 81),
#  (('Methodology/Principal', 'CHEMICAL'), 81),
#  (('LRTI', 'DISEASE'), 80),
#  (('community-acquired pneumonia', 'DISEASE'), 78),
#  (('KD', 'DISEASE'), 78),
#  (('FIV', 'CHEMICAL'), 78),
#  (('measles', 'DISEASE'), 78),
#  (('IFN', 'CHEMICAL'), 77),
#  (('AIDS', 'DISEASE'), 76),
#  (('BRD', 'DISEASE'), 76),
#  (('chloroquine', 'CHEMICAL'), 76),
#  (('anxiety', 'DISEASE'), 75),
#  (('S. pneumoniae', 'CHEMICAL'), 75),
#  (('respiratory syndrome virus', 'DISEASE'), 74),
#  (('TGEV infection', 'DISEASE'), 72),
#  (('parvovirus', 'DISEASE'), 71),
#  (('gastroenteritis', 'DISEASE'), 71),
#  (('bacterial infection', 'DISEASE'), 70),
#  (('CP', 'CHEMICAL'), 69),
#  (('pneumoniae', 'DISEASE'), 69),
#  (('wheezing', 'DISEASE'), 69),
#  (('coinfection', 'DISEASE'), 69),
#  (('respiratory diseases', 'DISEASE'), 68),
#  (('glucose', 'CHEMICAL'), 68),
#  (('TCM', 'CHEMICAL'), 68),
#  (('herpes simplex', 'DISEASE'), 68),
#  (('hemorrhagic fever', 'DISEASE'), 67),
#  (('RBD', 'DISEASE'), 67),
#  (('Ebola virus disease', 'DISEASE'), 67),
#  (('nitric oxide', 'CHEMICAL'), 66),
#  (('identity', 'DISEASE'), 66),
#  (('astrovirus', 'DISEASE'), 66),
#  (('melanoma', 'DISEASE'), 66),
#  (('S. aureus', 'CHEMICAL'), 66),
#  (('naïve', 'DISEASE'), 65),
#  (('flavivirus', 'DISEASE'), 64),
#  (('bacterial infections', 'DISEASE'), 64),
#  (('neuroinflammation', 'DISEASE'), 64),
#  (('tetherin', 'CHEMICAL'), 64),
#  (('human infections', 'DISEASE'), 63),
#  (('RTIs', 'CHEMICAL'), 63),
#  (('tyrosine', 'CHEMICAL'), 63),
#  (('quercetin', 'CHEMICAL'), 63),
#  (('Zn', 'CHEMICAL'), 63),
#  (('dehydration', 'DISEASE'), 62),
#  (('necrosis', 'DISEASE'), 62),
#  (('SARS-CoV infection', 'DISEASE'), 62),
#  (('viremia', 'DISEASE'), 61),
#  (('cancers', 'DISEASE'), 61),
#  (('calcium', 'CHEMICAL'), 60),
#  (('respiratory failure', 'DISEASE'), 60),
#  (('meningitis', 'DISEASE'), 60),
#  (('Pneumonia', 'DISEASE'), 59),
#  (('hypertension', 'DISEASE'), 59),
#  (('influenza virus infection', 'DISEASE'), 59),
#  (('Staphylococcus aureus', 'DISEASE'), 58),
#  (('HPAI', 'DISEASE'), 58),
#  (('gastroenteritis virus', 'DISEASE'), 58),
#  (('viral pneumonia', 'DISEASE'), 58),
#  (('https://doi.org/10', 'CHEMICAL'), 58),
#  (('lung injury', 'DISEASE'), 57),
#  (('zoonotic diseases', 'DISEASE'), 57),
#  (('CCHFV', 'DISEASE'), 57),
#  (('failure', 'DISEASE'), 56),
#  (('human disease', 'DISEASE'), 56),
#  (('illness', 'DISEASE'), 56),
#  (('febrile illness', 'DISEASE'), 56),
#  (('extract', 'CHEMICAL'), 56),
#  (('HIV-1 infection', 'DISEASE'), 56),
#  (('MP', 'DISEASE'), 56),
#  (('GA', 'CHEMICAL'), 56),
#  (('NPs', 'CHEMICAL'), 56),
#  (('MBL', 'CHEMICAL'), 56),
#  (('microcephaly', 'DISEASE'), 56),
#  (('Chikungunya', 'DISEASE'), 55),
#  (('acute respiratory syndrome coronavirus', 'DISEASE'), 55),
#  (('carbohydrate', 'CHEMICAL'), 55),
#  (('pertussis', 'DISEASE'), 55),
#  (('chronic obstructive pulmonary disease', 'DISEASE'), 53),
#  (('nucleoside', 'CHEMICAL'), 53),
#  (('HIV infection', 'DISEASE'), 52),
#  (('alanine', 'CHEMICAL'), 52),
#  (('pH1N1', 'DISEASE'), 52),
#  (('shock', 'DISEASE'), 51),
#  (('oseltamivir', 'CHEMICAL'), 51),
#  (('coronavirus infection', 'DISEASE'), 51),
#  (('Ebola', 'DISEASE'), 51),
#  (('CDV', 'DISEASE'), 51),
#  (('trypsin', 'CHEMICAL'), 50),
#  (('breast cancer', 'DISEASE'), 50),
#  (('LAMP', 'CHEMICAL'), 50),
#  (('zinc', 'CHEMICAL'), 50),
#  (('rabies', 'DISEASE'), 49),
#  (('lipopolysaccharide', 'CHEMICAL'), 49),
#  (('AA', 'CHEMICAL'), 49),
#  (('IBD', 'DISEASE'), 49),
#  (('WNV', 'DISEASE'), 49),
#  (('Mycobacterium tuberculosis', 'DISEASE'), 49),
#  (('EV71 infection', 'DISEASE'), 49),
#  (('viral disease', 'DISEASE'), 48),
#  (('NPC', 'DISEASE'), 48),
#  (('disorder', 'DISEASE'), 48),
#  (('NPA', 'CHEMICAL'), 48),
#  (('95%CI', 'CHEMICAL'), 48),
#  (('Ebola virus', 'DISEASE'), 48),
#  (('CM', 'DISEASE'), 48),
#  (('CHIKV infection', 'DISEASE'), 47),
#  (('fatality', 'DISEASE'), 47),
#  (('prostate cancer', 'DISEASE'), 47),
#  (('PRRSV infection', 'DISEASE'), 47),
#  (('SA', 'CHEMICAL'), 47),
#  (('JEV infection', 'DISEASE'), 47),
#  (('PTSD', 'DISEASE'), 46),
#  (('depression', 'DISEASE'), 46),
#  (('enteritis', 'DISEASE'), 46),
#  (('Na', 'CHEMICAL'), 46),
#  (('niclosamide', 'CHEMICAL'), 46),
#  (('acute lung injury', 'DISEASE'), 45),
#  (('zoonotic disease', 'DISEASE'), 45),
#  (('human diseases', 'DISEASE'), 45),
#  (('peritonitis', 'DISEASE'), 45),
#  (('Mycoplasma pneumoniae', 'DISEASE'), 45),
#  (('sialic acids', 'CHEMICAL'), 45),
#  (('HMGB1', 'CHEMICAL'), 45),
#  (('lysine', 'CHEMICAL'), 45),
#  (('human infection', 'DISEASE'), 44),
#  (('stroke', 'DISEASE'), 44),
#  (('sodium', 'CHEMICAL'), 44),
#  (('hepatitis virus', 'DISEASE'), 44),
#  (('CVB3', 'CHEMICAL'), 44),
#  (('PCD', 'DISEASE'), 44),
#  (('obesity', 'DISEASE'), 43),
#  (('conjugated', 'CHEMICAL'), 43),
#  (('HBV infection', 'DISEASE'), 43),
#  (('coronavirus (2019-nCoV)', 'DISEASE'), 43),
#  (('glycyrrhizin', 'CHEMICAL'), 43),
#  (('arthritis', 'DISEASE'), 42),
#  (('respiratory syndrome coronavirus', 'DISEASE'), 42),
#  (('dyspnea', 'DISEASE'), 42),
#  (('Infections', 'DISEASE'), 42),
#  (('multiple sclerosis', 'DISEASE'), 42),
#  (('MRSA', 'DISEASE'), 42),
#  (('Canada', 'DISEASE'), 42),
#  (('angiotensin', 'CHEMICAL'), 42),
#  (('PTB', 'DISEASE'), 42),
#  (('HCC', 'DISEASE'), 42),
#  (('DENV infection', 'DISEASE'), 42),
#  (('chikungunya', 'DISEASE'), 41),
#  (('SIR', 'DISEASE'), 41),
#  (('heart failure', 'DISEASE'), 41),
#  (('dengue fever', 'DISEASE'), 41),
#  (('resveratrol', 'CHEMICAL'), 41),
#  (('SFTS', 'DISEASE'), 41),
#  (('RA', 'DISEASE'), 41),
#  (('PPRV', 'DISEASE'), 41),
#  (('emodin', 'CHEMICAL'), 40),
#  (('IDV', 'CHEMICAL'), 40),
#  (('IM', 'CHEMICAL'), 40),
#  (('VEEV', 'CHEMICAL'), 40),
#  (('VZV', 'DISEASE'), 40),
#  (('glutathione', 'CHEMICAL'), 40),
#  (('IBV infection', 'DISEASE'), 40),
#  (('COX-2', 'CHEMICAL'), 39),
#  (('−', 'CHEMICAL'), 39),
#  (('Fever', 'DISEASE'), 39),
#  (('tumor necrosis', 'DISEASE'), 39),
#  (('flavonoids', 'CHEMICAL'), 39),
#  (('acute respiratory infections', 'DISEASE'), 39),
#  (('PE', 'DISEASE'), 39),
#  (('Th17', 'CHEMICAL'), 39),
#  (('comorbidity', 'DISEASE'), 39),
#  (('SFTSV', 'DISEASE'), 39),
#  (('RTI', 'CHEMICAL'), 39),
#  (('corticosteroids', 'CHEMICAL'), 38),
#  (('IBV', 'CHEMICAL'), 38),
#  (('tissue damage', 'DISEASE'), 38),
#  (('Enterovirus', 'DISEASE'), 38),
#  (('AM', 'CHEMICAL'), 38),
#  (('RV infection', 'DISEASE'), 38),
#  (('Li', 'CHEMICAL'), 38),
#  (('LRTIs', 'DISEASE'), 38),
#  (('heparin', 'CHEMICAL'), 37),
#  (('ethanol', 'CHEMICAL'), 37),
#  (('asthma exacerbations', 'DISEASE'), 37),
#  (("Alzheimer's disease", 'DISEASE'), 37),
#  (('FRI', 'CHEMICAL'), 37),
#  (('liver disease', 'DISEASE'), 37),
#  (('arginine', 'CHEMICAL'), 37),
#  (('ARTI', 'DISEASE'), 37),
#  (('Vpu', 'CHEMICAL'), 37),
#  (('HCoVs', 'DISEASE'), 36),
#  (('OH', 'CHEMICAL'), 36),
#  (('bioaerosol', 'CHEMICAL'), 36),
#  (('autoimmune diseases', 'DISEASE'), 36),
#  (('S.', 'CHEMICAL'), 36),
#  (('bacterium', 'CHEMICAL'), 36),
#  (('Leone', 'CHEMICAL'), 36),
#  (('watery diarrhea', 'DISEASE'), 36),
#  (('NLRP3', 'CHEMICAL'), 36),
#  (('NCP', 'CHEMICAL'), 36),
#  (('DI-RNAs', 'CHEMICAL'), 36),
#  (('respiratory symptoms', 'DISEASE'), 35),
#  (('pain', 'DISEASE'), 35),
#  (('iron', 'CHEMICAL'), 35),
#  (('lung cancer', 'DISEASE'), 35),
#  (('TCR', 'CHEMICAL'), 35),
#  (('CsA', 'CHEMICAL'), 35),
#  (('hepatocellular carcinoma', 'DISEASE'), 35),
#  (('E1', 'CHEMICAL'), 35),
#  (('Salmonella', 'DISEASE'), 34),
#  (('DMD', 'DISEASE'), 34),
#  (('cholera', 'DISEASE'), 34),
#  (('bacterial pneumonia', 'DISEASE'), 34),
#  (('acute infection', 'DISEASE'), 34),
#  (('lipids', 'CHEMICAL'), 34),
#  (('EV71', 'DISEASE'), 34),
#  (('nucleotide identity', 'CHEMICAL'), 34),
#  (('EAE', 'DISEASE'), 33),
#  (('human immunodeficiency virus (HIV)', 'DISEASE'), 33),
#  (('human immunodeficiency virus', 'DISEASE'), 33),
#  (('headache', 'DISEASE'), 33),
#  (('metastasis', 'DISEASE'), 33),
#  (('IAV infection', 'DISEASE'), 33),
#  (('silver', 'CHEMICAL'), 33),
#  (('MOPV', 'CHEMICAL'), 33),
#  (('chronic diseases', 'DISEASE'), 32),
#  (('lactate', 'CHEMICAL'), 32),
#  (('sore throat', 'DISEASE'), 32),
#  (('respiratory viral infections', 'DISEASE'), 32),
#  (('EBOV infection', 'DISEASE'), 32),
#  (('rapamycin', 'CHEMICAL'), 32),
#  (('Lactobacillus', 'CHEMICAL'), 32),
#  (('Dengue', 'DISEASE'), 32),
#  (('hypoxemia', 'DISEASE'), 32),
#  (('mouth disease', 'DISEASE'), 32),
#  (('CD', 'DISEASE'), 32),
#  (('IL-37', 'CHEMICAL'), 32),
#  (('ADV', 'CHEMICAL'), 32),
#  (('TMV', 'DISEASE'), 31),
#  (('NaCl', 'CHEMICAL'), 31),
#  (('adenosine', 'CHEMICAL'), 31),
#  (('smoking', 'CHEMICAL'), 31),
#  (('viral diarrhea', 'DISEASE'), 31),
#  (('SM', 'CHEMICAL'), 31),
#  (('osteonecrosis', 'DISEASE'), 31),
#  (('neurological disorders', 'DISEASE'), 31),
#  (('RVFV', 'DISEASE'), 31),
#  (('CPV-2c', 'CHEMICAL'), 31),
#  (('TGF-β', 'CHEMICAL'), 31),
#  (('psychological distress', 'DISEASE'), 30),
#  (('paramyxovirus', 'DISEASE'), 30),
#  (('EGCG', 'CHEMICAL'), 30),
#  (('natural infection', 'DISEASE'), 30),
#  (('tryptophan', 'CHEMICAL'), 30),
#  (('conjugate', 'CHEMICAL'), 30),
#  (('HSV-2', 'DISEASE'), 30),
#  (('HAE', 'DISEASE'), 30),
#  (('respiratory virus infections', 'DISEASE'), 30),
#  (('anemia', 'DISEASE'), 30),
#  (('Hepatitis E', 'DISEASE'), 30),
#  (('cirrhosis', 'DISEASE'), 30),
#  (('PD', 'DISEASE'), 30),
#  (('tumour', 'DISEASE'), 29),
#  (('Nipah', 'DISEASE'), 29),
#  (('SE', 'DISEASE'), 29),
#  (('Plasmodium falciparum', 'DISEASE'), 29),
#  (('alcohol', 'CHEMICAL'), 29),
#  (('C. difficile', 'DISEASE'), 29),
#  (('DNA damage', 'DISEASE'), 29),
#  (('steroid', 'CHEMICAL'), 29),
#  (('septic shock', 'DISEASE'), 29),
#  (('autoimmunity', 'DISEASE'), 29),
#  (('secondary infections', 'DISEASE'), 29),
#  (('fatigue', 'DISEASE'), 29),
#  (('Guillain-Barré', 'CHEMICAL'), 29),
#  (('GM-CSF', 'CHEMICAL'), 28),
#  (('infectious bronchitis', 'DISEASE'), 28),
#  (('AOM', 'DISEASE'), 28),
#  (('thrombocytopenia', 'DISEASE'), 28),
#  (('paralysis', 'DISEASE'), 28),
#  (('rash', 'DISEASE'), 28),
#  (('SP', 'CHEMICAL'), 28),
#  (('disability', 'DISEASE'), 28),
#  (('neurodegeneration', 'DISEASE'), 28),
#  (('viral hepatitis', 'DISEASE'), 28),
#  (('fatty acid', 'CHEMICAL'), 28),
#  (('CHOP', 'CHEMICAL'), 28),
#  (('RSV infections', 'DISEASE'), 28),
#  (('IL-1b', 'CHEMICAL'), 28),
#  (('poly(I', 'CHEMICAL'), 28),
#  (('HFRS', 'DISEASE'), 28),
#  (('HBsAg', 'CHEMICAL'), 28),
#  (('HPS', 'DISEASE'), 28),
#  (('rheumatoid arthritis', 'DISEASE'), 28),
#  (('curcumin', 'CHEMICAL'), 28),
#  (('acute respiratory illness', 'DISEASE'), 27),
#  (('airway inflammation', 'DISEASE'), 27),
#  (('lymphopenia', 'DISEASE'), 27),
#  (('μg/mL', 'CHEMICAL'), 27),
#  (('H1N1 influenza', 'DISEASE'), 27),
#  (('oligonucleotide', 'CHEMICAL'), 27),
#  (('necrotic', 'DISEASE'), 27),
#  (('communicable diseases', 'DISEASE'), 27),
#  (('Viral infections', 'DISEASE'), 27),
#  (('acute respiratory infection', 'DISEASE'), 27),
#  (('viral respiratory infections', 'DISEASE'), 27),
#  (('CF', 'DISEASE'), 27),
#  (('neurological complications', 'DISEASE'), 27),
#  (('MIC', 'CHEMICAL'), 27),
#  (('respiratory tract disease', 'DISEASE'), 26),
#  (('human immunodeficiency virus type 1', 'DISEASE'), 26),
#  (('acute respiratory distress syndrome', 'DISEASE'), 26),
#  (('myalgia', 'DISEASE'), 26),
#  (('chronic infection', 'DISEASE'), 26),
#  (('malignancy', 'DISEASE'), 26),
#  (('superoxide', 'CHEMICAL'), 26),
#  (('NPS', 'CHEMICAL'), 26),
#  (('autoimmune disease', 'DISEASE'), 26),
#  (('Respiratory Syndrome Coronavirus', 'DISEASE'), 26),
#  (('anorexia', 'DISEASE'), 26),
#  (('griffithsin', 'CHEMICAL'), 26),
#  (('coronavirus disease', 'DISEASE'), 26),
#  (('CCHF', 'DISEASE'), 26),
#  (('vitamin D', 'CHEMICAL'), 26),
#  (('TS', 'DISEASE'), 26),
#  (('OME', 'DISEASE'), 25),
#  (('acute respiratory tract infections', 'DISEASE'), 25),
#  (('interstitial pneumonia', 'DISEASE'), 25),
#  (('Cancer', 'DISEASE'), 25),
#  (('GS-5734', 'CHEMICAL'), 25),
#  (('zanamivir', 'CHEMICAL'), 25),
#  (('hypoxia', 'DISEASE'), 25),
#  (('ALRI', 'DISEASE'), 25),
#  (('lycorine', 'CHEMICAL'), 25),
#  (('hepatitis A', 'DISEASE'), 25),
#  (('bafilomycin', 'CHEMICAL'), 25),
#  (('Toxoplasma gondii', 'DISEASE'), 25),
#  (('lung inflammation', 'DISEASE'), 25),
#  (('inflammatory diseases', 'DISEASE'), 25),
#  (('ON', 'CHEMICAL'), 25),
#  (('coronavirus infections', 'DISEASE'), 25),
#  (('pulmonary edema', 'DISEASE'), 25),
#  (('Respiratory syncytial virus', 'DISEASE'), 25),
#  (('OAS', 'CHEMICAL'), 25),
#  (('myocarditis', 'DISEASE'), 25),
#  (('Tuberculosis', 'DISEASE'), 25),
#  (('carbon', 'CHEMICAL'), 25),
#  (('IFN-α/β', 'CHEMICAL'), 25),
#  (('A(H3N2', 'CHEMICAL'), 25),
#  (('respiratory illnesses', 'DISEASE'), 24),
#  (('leishmaniasis', 'DISEASE'), 24),
#  (('CoV infection', 'DISEASE'), 24),
#  (('MERS-CoV infections', 'DISEASE'), 24),
#  (('creatinine', 'CHEMICAL'), 24),
#  (('dengue infection', 'DISEASE'), 24),
#  (('HCoV-OC43', 'DISEASE'), 24),
#  (('AMR', 'CHEMICAL'), 24),
#  (('thrombocytopenia syndrome', 'DISEASE'), 24),
#  (('Lassa fever', 'DISEASE'), 24),
#  (('leptospirosis', 'DISEASE'), 24),
#  (('NE', 'CHEMICAL'), 24),
#  (('torovirus', 'CHEMICAL'), 24),
#  (('outbreak', 'DISEASE'), 24),
#  (('influenza A virus', 'DISEASE'), 24),
#  (('glioma', 'DISEASE'), 24),
#  (('pancreatitis', 'DISEASE'), 24),
#  (('Ang II', 'CHEMICAL'), 24),
#  (('Diarrhea', 'DISEASE'), 24),
#  (('atherosclerosis', 'DISEASE'), 24),
#  (('HKU4', 'CHEMICAL'), 24),
#  (('DTT', 'CHEMICAL'), 24),
#  (('FP', 'CHEMICAL'), 24),
#  (('silvestrol', 'CHEMICAL'), 24),
#  (('glycine', 'CHEMICAL'), 24),
#  (('phosphate', 'CHEMICAL'), 24),
#  (('RBV', 'CHEMICAL'), 24),
#  (('SCD', 'DISEASE'), 24),
#  (('IPD', 'DISEASE'), 24),
#  (('acute diarrhea', 'DISEASE'), 23),
#  (('heart disease', 'DISEASE'), 23),
#  (('licorice', 'CHEMICAL'), 23),
#  (('conjunctivitis', 'DISEASE'), 23),
#  (('contagious disease', 'DISEASE'), 23),
#  (('TNFα', 'DISEASE'), 23),
#  (('steroids', 'CHEMICAL'), 23),
#  (('TAM', 'CHEMICAL'), 23),
#  (('septic', 'DISEASE'), 23),
#  (('Mn', 'CHEMICAL'), 23),
#  (('nucleosides', 'CHEMICAL'), 23),
#  (('alveolar damage', 'DISEASE'), 23),
#  (('luminal', 'CHEMICAL'), 23),
#  (('BFA', 'CHEMICAL'), 23),
#  (('asthmatic', 'DISEASE'), 23),
#  (('SFTSV infection', 'DISEASE'), 23),
#  (('neurological diseases', 'DISEASE'), 23),
#  (('DHF', 'DISEASE'), 23),
#  (('GBS', 'DISEASE'), 23),
#  (('DEN-IM', 'CHEMICAL'), 23),
#  (('DENV-2', 'CHEMICAL'), 23),
#  (('PR8', 'CHEMICAL'), 23),
#  (('HuNoV', 'DISEASE'), 23),
#  (('FAs', 'CHEMICAL'), 23),
#  (('PDCoV infection', 'DISEASE'), 23),
#  (('CRC', 'DISEASE'), 22),
#  (('S. cerevisiae', 'CHEMICAL'), 22),
#  (('bacteremia', 'DISEASE'), 22),
#  (('A(H7N9', 'CHEMICAL'), 22),
#  (('trauma', 'DISEASE'), 22),
#  (('cardiovascular diseases', 'DISEASE'), 22),
#  (('influenza A virus infection', 'DISEASE'), 22),
#  (('neurodegenerative diseases', 'DISEASE'), 22),
#  (('pyrimidine', 'CHEMICAL'), 22),
#  (('angiotensin II', 'CHEMICAL'), 22),
#  (('Plasmodium', 'DISEASE'), 22),
#  (('UTI', 'DISEASE'), 22),
#  (('GVHD', 'DISEASE'), 22),
#  (('Hepatitis B', 'DISEASE'), 22),
#  (('anti-HCV', 'DISEASE'), 22),
#  (('NEC', 'DISEASE'), 22),
#  (('TBI', 'DISEASE'), 22),
#  (('birth defects', 'DISEASE'), 22),
#  (('visceral leishmaniasis', 'DISEASE'), 22),
#  (('TM', 'CHEMICAL'), 22),
#  (('S-INDEL', 'CHEMICAL'), 22),
#  (('CVB3 infection', 'DISEASE'), 22),
#  (('hepatitis E', 'DISEASE'), 21),
#  (('penicillin', 'CHEMICAL'), 21),
#  (('coronavirus 229E', 'DISEASE'), 21),
#  (('cAMP', 'CHEMICAL'), 21),
#  (('cytidine', 'CHEMICAL'), 21),
#  (('AECOPD', 'DISEASE'), 21),
#  (('primary infection', 'DISEASE'), 21),
#  (('Pseudomonas aeruginosa', 'DISEASE'), 21),
#  (('fatty acids', 'CHEMICAL'), 21),
#  (('HSV-1 infection', 'DISEASE'), 21),
#  (('arthralgia', 'DISEASE'), 21),
#  (('pleural effusion', 'DISEASE'), 21),
#  (('heparan sulfate', 'CHEMICAL'), 21),
#  (('IgE', 'CHEMICAL'), 21),
#  (('mumps', 'DISEASE'), 21),
#  (('viral encephalitis', 'DISEASE'), 21),
#  (('ADP-ribose', 'CHEMICAL'), 21),
#  (('P. vivax', 'DISEASE'), 21),
#  (('LAB', 'CHEMICAL'), 21),
#  (('MxA', 'CHEMICAL'), 21),
#  (('otitis', 'DISEASE'), 20),
#  (('VAP', 'DISEASE'), 20),
#  (('Coronavirus', 'DISEASE'), 20),
#  (('Kawasaki disease', 'DISEASE'), 20),
#  (('A/H1N1', 'DISEASE'), 20),
#  (('neutropenia', 'DISEASE'), 20),
#  (('blood-brain', 'DISEASE'), 20),
#  (('SLE', 'DISEASE'), 20),
#  (('rotavirus infection', 'DISEASE'), 20),
#  (('cardiovascular disease', 'DISEASE'), 20),
#  (('H1N1 infection', 'DISEASE'), 20),
#  (('gastrointestinal tract', 'DISEASE'), 20),
#  (('sucrose', 'CHEMICAL'), 20),
#  (('G6PD deficiency', 'DISEASE'), 20),
#  (('schistosomiasis', 'DISEASE'), 20),
#  (('CHF', 'DISEASE'), 20),
#  (('IPC', 'CHEMICAL'), 20),
#  (('AKI', 'DISEASE'), 20),
#  (('NSCLC', 'DISEASE'), 20),
#  (('Rift', 'DISEASE'), 20),
#  (('Viral infection', 'DISEASE'), 20),
#  (('Cryptosporidium spp', 'DISEASE'), 20),
#  (('2019-nCoV infection', 'DISEASE'), 20),
#  (('fungal infections', 'DISEASE'), 20),
#  (('PAR', 'CHEMICAL'), 20),
#  (('OAS', 'DISEASE'), 20),
#  (('Newcastle disease virus', 'DISEASE'), 20),
#  (('nucleolin', 'CHEMICAL'), 20),
#  (('MRSA', 'CHEMICAL'), 20),
#  (('influenza infections', 'DISEASE'), 20),
#  (('ursolic acid', 'CHEMICAL'), 20),
#  (('DA', 'CHEMICAL'), 19),
#  (('colorectal cancer', 'DISEASE'), 19),
#  (('acute respiratory failure', 'DISEASE'), 19),
#  (('betacoronavirus', 'CHEMICAL'), 19),
#  (('respiratory tract', 'DISEASE'), 19),
#  (('PCP', 'DISEASE'), 19),
#  (('communicable disease', 'DISEASE'), 19),
#  (('EBV infection', 'DISEASE'), 19),
#  (('TG', 'DISEASE'), 19),
#  (('hemorrhage', 'DISEASE'), 19),
#  (('polyphenols', 'CHEMICAL'), 19),
#  (('respiratory distress', 'DISEASE'), 19),
#  (('enteric disease', 'DISEASE'), 19),
#  (('weight gain', 'DISEASE'), 19),
#  (('MHV infection', 'DISEASE'), 19),
#  (('coronavirus disease 2019', 'DISEASE'), 19),
#  (('influenza B', 'DISEASE'), 19),
#  (('ONFH', 'DISEASE'), 19),
#  (('leucine', 'CHEMICAL'), 19),
#  (('AuNPs', 'CHEMICAL'), 19),
#  (('H1N1 virus', 'DISEASE'), 19),
#  (('colistin', 'CHEMICAL'), 19),
#  (('Leishmania', 'DISEASE'), 19),
#  (('Hepatitis C virus', 'DISEASE'), 19),
#  (('biotin', 'CHEMICAL'), 19),
#  (('CKD', 'DISEASE'), 19),
#  (('HCoV-229E', 'CHEMICAL'), 19),
#  (('xx xx xxxx', 'CHEMICAL'), 19),
#  (('TMD', 'DISEASE'), 19),
#  (('Tunisia', 'DISEASE'), 19),
#  (('Lf', 'CHEMICAL'), 19),
#  (('A/H7N9', 'CHEMICAL'), 19),
#  (('T. gondii infection', 'DISEASE'), 19),
#  (('VP', 'CHEMICAL'), 19),
#  (('YPFS', 'CHEMICAL'), 19),
#  (('SB', 'CHEMICAL'), 19),
#  (('vasculitis', 'DISEASE'), 18),
#  (('proline', 'CHEMICAL'), 18),
#  (('chloride', 'CHEMICAL'), 18),
#  (('FA', 'CHEMICAL'), 18),
#  (('edema', 'DISEASE'), 18),
#  (('σ', 'CHEMICAL'), 18),
#  (('somni', 'DISEASE'), 18),
#  (('hydrogen', 'CHEMICAL'), 18),
#  (('PDR', 'DISEASE'), 18),
#  (('nosocomial infections', 'DISEASE'), 18),
#  (('JE', 'DISEASE'), 18),
#  (('virus-specific', 'CHEMICAL'), 18),
#  (('LA', 'CHEMICAL'), 18),
#  (('GM', 'CHEMICAL'), 18),
#  (('coronavirus pneumonia', 'DISEASE'), 18),
#  (('TNF-a', 'CHEMICAL'), 18),
#  (('ARTIs', 'DISEASE'), 18),
#  (('Chloroquine', 'CHEMICAL'), 18),
#  (('gastric cancer', 'DISEASE'), 18),
#  (('OA', 'DISEASE'), 18),
#  (('HBeAg', 'CHEMICAL'), 18),
#  (('sneezing', 'DISEASE'), 18),
#  (('BEN', 'DISEASE'), 18),
#  (('CQ', 'CHEMICAL'), 18),
#  (('DENV-3', 'DISEASE'), 18),
#  (('NH 4 Cl', 'CHEMICAL'), 18),
#  (('HAdV-55', 'CHEMICAL'), 18),
#  (('bortezomib', 'CHEMICAL'), 18),
#  (('SV-A', 'CHEMICAL'), 18),
#  (('Scotophilus', 'CHEMICAL'), 18),
#  (('organ dysfunction', 'DISEASE'), 17),
#  (('infectious disease outbreak', 'DISEASE'), 17),
#  (('chronic disease', 'DISEASE'), 17),
#  (('zoonotic infections', 'DISEASE'), 17),
#  (('S. suis', 'DISEASE'), 17),
#  (('methanol', 'CHEMICAL'), 17),
#  (('hydrogen peroxide', 'CHEMICAL'), 17),
#  (('respiratory virus infection', 'DISEASE'), 17),
#  (('ozone', 'CHEMICAL'), 17),
#  (('astroviruses', 'DISEASE'), 17),
#  (('shortness of breath', 'DISEASE'), 17),
#  (('HEV infection', 'DISEASE'), 17),
#  (('pneumonitis', 'DISEASE'), 17),
#  (('GII.4', 'DISEASE'), 17),
#  (('SARS-related', 'CHEMICAL'), 17),
#  (('allergy', 'DISEASE'), 17),
#  (('bronchiectasis', 'DISEASE'), 17),
#  (('coxsackievirus', 'CHEMICAL'), 17),
#  (('atelectasis', 'DISEASE'), 17),
#  (('PLA', 'CHEMICAL'), 17),
#  (('MSCs', 'CHEMICAL'), 17),
#  (('schizophrenia', 'DISEASE'), 17),
#  (('HAM/TSP', 'DISEASE'), 17),
#  (('T2D', 'DISEASE'), 17),
#  (('respiratory infectious diseases', 'DISEASE'), 17),
#  (('liver cirrhosis', 'DISEASE'), 17),
#  (('neurological disease', 'DISEASE'), 17),
#  (('URTIs', 'DISEASE'), 17),
#  (('jaundice', 'DISEASE'), 17),
#  (('infectious bronchitis virus', 'DISEASE'), 17),
#  (('amino acid identity', 'CHEMICAL'), 17),
#  (('PID', 'DISEASE'), 17),
#  (('lymphocytic choriomeningitis virus', 'DISEASE'), 17),
#  (('liver injury', 'DISEASE'), 17),
#  (('SBV', 'DISEASE'), 17),
#  (('Enterobacteriaceae', 'CHEMICAL'), 17),
#  (('stomatitis', 'DISEASE'), 17),
#  (("Kaposi's sarcoma-associated herpesvirus", 'DISEASE'), 17),
#  (('Niclosamide', 'CHEMICAL'), 17),
#  (('CRF', 'DISEASE'), 17),
#  (('Herpes simplex', 'DISEASE'), 17),
#  (('SIV infection', 'DISEASE'), 17),
#  (('IAV infections', 'DISEASE'), 17),
#  (('CWE', 'CHEMICAL'), 17),
#  (('surfactin', 'CHEMICAL'), 17),
#  (('cervical cancer', 'DISEASE'), 17),
#  (('HMPV infection', 'DISEASE'), 17),
#  (('PGE 2', 'CHEMICAL'), 16),
#  (('respiratory syndrome-associated coronavirus', 'DISEASE'), 16),
#  (('IFN-a', 'CHEMICAL'), 16),
#  (('nucleic acid-based', 'CHEMICAL'), 16),
#  (('AMI', 'CHEMICAL'), 16),
#  (('H5N1 infection', 'DISEASE'), 16),
#  (('nosocomial infection', 'DISEASE'), 16),
#  (('osteoporosis', 'DISEASE'), 16),
#  (('SCID', 'DISEASE'), 16),
#  (('neutrophilia', 'DISEASE'), 16),
#  (('multiple infections', 'DISEASE'), 16),
#  (('WNV infection', 'DISEASE'), 16),
#  (('acute gastroenteritis', 'DISEASE'), 16),
#  (('paracetamol', 'CHEMICAL'), 16),
#  (('high-dose', 'CHEMICAL'), 16),
#  (('serine', 'CHEMICAL'), 16),
#  (('lung disease', 'DISEASE'), 16),
#  (('IFITM2', 'CHEMICAL'), 16),
#  (('methylprednisolone', 'CHEMICAL'), 16),
#  (('TLR2', 'CHEMICAL'), 16),
#  (('LiCl', 'CHEMICAL'), 16),
#  (('EV-A71', 'CHEMICAL'), 16),
#  (('Cryptosporidium', 'DISEASE'), 16),
#  (('dengue virus', 'DISEASE'), 16),
#  (('herpes', 'DISEASE'), 16),
#  (('potassium', 'CHEMICAL'), 16),
#  (('Mg', 'CHEMICAL'), 16),
#  (('SARS-CoV-2 infection', 'DISEASE'), 16),
#  (('sgmRNA', 'CHEMICAL'), 16),
#  (('mycetoma', 'DISEASE'), 16),
#  (('pomegranate', 'CHEMICAL'), 16),
#  (('ALS', 'DISEASE'), 16),
#  (('DENV-2', 'DISEASE'), 16),
#  (('HT', 'DISEASE'), 16),
#  (('PRV infection', 'DISEASE'), 16),
#  (('OVA', 'CHEMICAL'), 16),
#  (('IPF', 'DISEASE'), 16),
#  (('DI-RNA', 'CHEMICAL'), 16),
#  (('cardiovirus', 'CHEMICAL'), 16),
#  (('C. trachomatis', 'DISEASE'), 16),
#  (('apoD', 'CHEMICAL'), 16),
#  (('TNBC', 'DISEASE'), 16),
#  (('NAIS', 'DISEASE'), 16),
#  (('OFSCs', 'CHEMICAL'), 16),
#  (('Emodin', 'CHEMICAL'), 15),
#  (('protozoan', 'DISEASE'), 15),
#  (('ventilator-associated pneumonia', 'DISEASE'), 15),
#  (('guanosine', 'CHEMICAL'), 15),
#  (('febrile seizures', 'DISEASE'), 15),
#  (('AOM', 'CHEMICAL'), 15),
#  (('Amino acid', 'CHEMICAL'), 15),
#  (('panic', 'DISEASE'), 15),
#  (('methicillin-resistant Staphylococcus aureus', 'DISEASE'), 15),
#  (('Clostridium difficile', 'DISEASE'), 15),
#  (('confusion', 'DISEASE'), 15),
#  (('dengue hemorrhagic fever', 'DISEASE'), 15),
#  (('SARS-CoV.', 'CHEMICAL'), 15),
#  (('La', 'CHEMICAL'), 15),
#  (('JA', 'CHEMICAL'), 15),
#  (('liposomes', 'CHEMICAL'), 15),
#  (('cardiac arrest', 'DISEASE'), 15),
#  (('autoimmune encephalomyelitis', 'DISEASE'), 15),
#  (('SARS coronavirus', 'DISEASE'), 15),
#  (('TCA', 'CHEMICAL'), 15),
#  (('Multiple sclerosis', 'DISEASE'), 15),
#  (('immunodeficiency', 'DISEASE'), 15),
#  (('amantadine', 'CHEMICAL'), 15),
#  (('Sepsis', 'DISEASE'), 15),
#  (('urea', 'CHEMICAL'), 15),
#  (('malignancies', 'DISEASE'), 15),
#  (('weakness', 'DISEASE'), 15),
#  (('H1N1v', 'DISEASE'), 15),
#  (('acyclovir', 'CHEMICAL'), 15),
#  (('Betacoronavirus', 'CHEMICAL'), 15),
#  (('hypertrophy', 'DISEASE'), 15),
#  (('uridine', 'CHEMICAL'), 15),
#  (('LTBI', 'DISEASE'), 15),
#  (('chronic infections', 'DISEASE'), 15),
#  (('aspartate', 'CHEMICAL'), 15),
#  (('lung damage', 'DISEASE'), 15),
#  (('Klebsiella pneumoniae', 'CHEMICAL'), 15),
#  (('DM', 'DISEASE'), 15),
#  (('Hepatitis C', 'DISEASE'), 15),
#  (('bleomycin', 'CHEMICAL'), 15),
#  (('NAD', 'CHEMICAL'), 15),
#  (('inflammatory bowel disease', 'DISEASE'), 15),
#  (('airway disease', 'DISEASE'), 15),
#  (('liver damage', 'DISEASE'), 15),
#  (('encephalomyelitis', 'DISEASE'), 15),
#  (('renal syndrome', 'DISEASE'), 15),
#  (('MK', 'CHEMICAL'), 15),
#  (('Candida albicans', 'DISEASE'), 15),
#  (('glutamine', 'CHEMICAL'), 15),
#  (('GSH', 'CHEMICAL'), 15),
#  (('T2DM', 'DISEASE'), 15),
#  (('Malassezia', 'DISEASE'), 15),
#  (('NiV infection', 'DISEASE'), 15),
#  (('DIP', 'CHEMICAL'), 15),
#  (('DENV infections', 'DISEASE'), 15),
#  (('TAA', 'DISEASE'), 15),
#  (('ENC', 'CHEMICAL'), 15),
#  (('HTNV infection', 'DISEASE'), 15),
#  (('milk replacer', 'DISEASE'), 15),
#  (('WYMV', 'CHEMICAL'), 15),
#  (('OSCC', 'DISEASE'), 15),
#  (('UA', 'CHEMICAL'), 15),
#  (('HIV infections', 'DISEASE'), 14),
#  (('epilepsy', 'DISEASE'), 14),
#  (('diabetes mellitus', 'DISEASE'), 14),
#  (('leukopenia', 'DISEASE'), 14),
#  (('formaldehyde', 'CHEMICAL'), 14),
#  (('rhinorrhea', 'DISEASE'), 14),
#  (('PPARα', 'CHEMICAL'), 14),
#  (('rhinovirus infection', 'DISEASE'), 14),
#  (('flavonoid', 'CHEMICAL'), 14),
#  (('lethargy', 'DISEASE'), 14),
#  (('demyelinating disease', 'DISEASE'), 14),
#  (('PVP-I', 'CHEMICAL'), 14),
#  (('SAFV', 'CHEMICAL'), 14),
#  (('BOOP', 'DISEASE'), 14),
#  (('afebrile', 'DISEASE'), 14),
#  (('polyethylene glycol', 'CHEMICAL'), 14),
#  (('swelling', 'DISEASE'), 14),
#  (('NAFLD', 'DISEASE'), 14),
#  (('prematurity', 'DISEASE'), 14),
#  (('diabetic', 'DISEASE'), 14),
#  (('DMSO', 'CHEMICAL'), 14),
#  (('nausea', 'DISEASE'), 14),
#  (('renal failure', 'DISEASE'), 14),
#  (('diarrheal', 'DISEASE'), 14),
#  (('OM', 'CHEMICAL'), 14),
#  (('seizures', 'DISEASE'), 14),
#  (('Acute Respiratory Syndrome', 'DISEASE'), 14),
#  (('amino', 'CHEMICAL'), 14),
#  (('vaccinia virus', 'DISEASE'), 14),
#  (('carbapenem', 'CHEMICAL'), 14),
#  (('ICH', 'DISEASE'), 14),
#  (('estrogen', 'CHEMICAL'), 14),
#  (('H7N9 infection', 'DISEASE'), 14),
#  (('viraemia', 'DISEASE'), 14),
#  (('phospholipids', 'CHEMICAL'), 14),
#  (('Firmicutes', 'CHEMICAL'), 14),
#  (('appendicitis', 'DISEASE'), 14),
#  (('H7', 'CHEMICAL'), 14),
#  (('colitis', 'DISEASE'), 14),
#  (('Griffithsin', 'CHEMICAL'), 14),
#  (('Lassa virus', 'DISEASE'), 14),
#  (('SARS-coronavirus', 'CHEMICAL'), 14),
#  (('AQ', 'CHEMICAL'), 14),
#  (('Kilifi', 'CHEMICAL'), 14),
#  (('DOX', 'CHEMICAL'), 14),
#  (('toltrazuril', 'CHEMICAL'), 14),
#  (('HSCARG', 'CHEMICAL'), 14),
#  (('retinoic', 'CHEMICAL'), 14),
#  (('scrub typhus', 'DISEASE'), 14),
#  (('NDM-1', 'CHEMICAL'), 14),
#  (('T&CM', 'CHEMICAL'), 14),
#  (('myricetin', 'CHEMICAL'), 14),
#  (('TCDD', 'CHEMICAL'), 14),
#  (('CIA', 'DISEASE'), 14),
#  (('HAL', 'CHEMICAL'), 14),
#  (('fenofibrate', 'CHEMICAL'), 14),
#  (('RANTES', 'CHEMICAL'), 13),
#  (('AML', 'DISEASE'), 13),
#  (('depressive symptoms', 'DISEASE'), 13),
#  (('CPV infection', 'DISEASE'), 13),
#  (('Streptococcus suis', 'DISEASE'), 13),
#  (('São Paulo', 'CHEMICAL'), 13),
#  (('sinusitis', 'DISEASE'), 13),
#  (('TRP', 'CHEMICAL'), 13),
#  (('pharyngitis', 'DISEASE'), 13),
#  (('respiratory viral infection', 'DISEASE'), 13),
#  (('SNAP', 'CHEMICAL'), 13),
#  (('na', 'CHEMICAL'), 13),
#  (('pneumococcus', 'DISEASE'), 13),
#  (('pulmonary infection', 'DISEASE'), 13),
#  (('HEPES', 'CHEMICAL'), 13),
#  (('interferon (IFN', 'CHEMICAL'), 13),
#  (('secondary infection', 'DISEASE'), 13),
#  (('aseptic meningitis', 'DISEASE'), 13),
#  (('gastrointestinal disease', 'DISEASE'), 13),
#  (('tachypnea', 'DISEASE'), 13),
#  (('macrolide', 'CHEMICAL'), 13),
#  (('statins', 'CHEMICAL'), 13),
#  (('tick-borne encephalitis', 'DISEASE'), 13),
#  (('streptomycin', 'CHEMICAL'), 13),
#  (('galactose', 'CHEMICAL'), 13),
#  (('dsRNAs', 'CHEMICAL'), 13),
#  (('LRF', 'CHEMICAL'), 13),
#  (('Entresto®', 'CHEMICAL'), 13),
#  (('Bacteroidetes', 'CHEMICAL'), 13),
#  (('NTM', 'CHEMICAL'), 13),
#  (('allergic rhinitis', 'DISEASE'), 13),
#  (('green', 'CHEMICAL'), 13),
#  (('neuroblastoma', 'DISEASE'), 13),
#  (('coronavirus infectious bronchitis', 'DISEASE'), 13),
#  (('toxoplasmosis', 'DISEASE'), 13),
#  (('organ failure', 'DISEASE'), 13),
#  (('Chlamydia trachomatis', 'DISEASE'), 13),
#  (('poliomyelitis', 'DISEASE'), 13),
#  (('Flavivirus', 'DISEASE'), 13),
#  (('hyperthermia', 'DISEASE'), 13),
#  (('amyloid A', 'CHEMICAL'), 13),
#  (('ICS', 'CHEMICAL'), 13),
#  (('MSM', 'CHEMICAL'), 13),
#  (('allergic', 'DISEASE'), 13),
#  (('ALV-J infection', 'DISEASE'), 13),
#  (('MDS', 'DISEASE'), 13),
#  (('viroporin', 'CHEMICAL'), 13),
#  (('influenza A virus (IAV)', 'DISEASE'), 13),
#  (('PEG', 'CHEMICAL'), 13),
#  (('FSHD', 'DISEASE'), 13),
#  (('candidemia', 'DISEASE'), 13),
#  (('ExoN', 'CHEMICAL'), 13),
#  (('P-UR', 'CHEMICAL'), 13),
#  (('PKDL', 'DISEASE'), 13),
#  (('hyponatremia', 'DISEASE'), 13),
#  (('miR-27b', 'CHEMICAL'), 13),
#  (('ACEIs', 'CHEMICAL'), 13),
#  (('cisplatin', 'CHEMICAL'), 13),
#  (('reproductive failure', 'DISEASE'), 13),
#  (('bleeding', 'DISEASE'), 13),
#  (('HRV infections', 'DISEASE'), 13),
#  (('PGE', 'CHEMICAL'), 13),
#  (('CSFV', 'DISEASE'), 13),
#  (('liver diseases', 'DISEASE'), 13),
#  (('PCV2 infection', 'DISEASE'), 13),
#  (('Ebola virus infection', 'DISEASE'), 13),
#  (('FTD', 'DISEASE'), 13),
#  (('phenolic', 'CHEMICAL'), 13),
#  (('gemcitabine', 'CHEMICAL'), 13),
#  (('atopy', 'DISEASE'), 13),
#  (('CDV infection', 'DISEASE'), 13),
#  (('ATL', 'DISEASE'), 13),
#  (('S-goitrin', 'CHEMICAL'), 13),
#  (('miR-155', 'CHEMICAL'), 13),
#  (('CD200R', 'CHEMICAL'), 13),
#  (('TRIM56', 'DISEASE'), 13),
#  (('HCP', 'DISEASE'), 12),
#  (('azithromycin', 'CHEMICAL'), 12),
#  (('infectivity', 'DISEASE'), 12),
#  (('Salmonella spp', 'DISEASE'), 12),
#  (('seizure', 'DISEASE'), 12),
#  (('amoxicillin', 'CHEMICAL'), 12),
#  (('HBoV infection', 'DISEASE'), 12),
#  (('neurodegenerative disease', 'DISEASE'), 12),
#  (('acute respiratory tract infection', 'DISEASE'), 12),
#  (('ovarian cancer', 'DISEASE'), 12),
#  (('HK', 'CHEMICAL'), 12),
#  (('tetracycline', 'CHEMICAL'), 12),
#  (('MI', 'DISEASE'), 12),
#  (('abdominal pain', 'DISEASE'), 12),
#  (('hydrogen bonds', 'CHEMICAL'), 12),
#  (('encephalopathy', 'DISEASE'), 12),
#  (('Shigella', 'DISEASE'), 12),
#  (('diarrhoeal', 'DISEASE'), 12),
#  (('gastroenteritis coronavirus', 'DISEASE'), 12),
#  (('SARS infection', 'DISEASE'), 12),
#  (('Al', 'CHEMICAL'), 12),
#  (('bronchopneumonia', 'DISEASE'), 12),
#  (('hypokalemia', 'DISEASE'), 12),
#  (('neurodegenerative disorders', 'DISEASE'), 12),
#  (('H3N2', 'CHEMICAL'), 12),
#  (('brefeldin A', 'CHEMICAL'), 12),
#  (('RS', 'DISEASE'), 12),
#  (('respiratory coronavirus', 'DISEASE'), 12),
#  (('macrolides', 'CHEMICAL'), 12),
#  (('ESRD', 'DISEASE'), 12),
#  (('infectious complications', 'DISEASE'), 12),
#  (('syndrome-coronavirus', 'CHEMICAL'), 12),
#  (('Ebola infection', 'DISEASE'), 12),
#  (('IL-35', 'CHEMICAL'), 12),
#  (('norovirus infection', 'DISEASE'), 12),
#  (('ORT', 'CHEMICAL'), 12),
#  (('pulmonary lesions', 'DISEASE'), 12),
#  (('hMPV infection', 'DISEASE'), 12),
#  (('henipavirus', 'DISEASE'), 12),
#  (('pimobendan', 'CHEMICAL'), 12),
#  (('polyamine', 'CHEMICAL'), 12),
#  (('H1N1 influenza virus', 'DISEASE'), 12),
#  (('viral vectors', 'DISEASE'), 12),
#  (('CIT', 'CHEMICAL'), 12),
#  (('influenza virus infections', 'DISEASE'), 12),
#  (('triphosphate', 'CHEMICAL'), 12),
#  (('icariin', 'CHEMICAL'), 12),
#  (('tick-borne', 'DISEASE'), 12),
#  (('RDT', 'DISEASE'), 12),
#  (('PGG', 'CHEMICAL'), 12),
#  (('congenital malformations', 'DISEASE'), 12),
#  (('atopic dermatitis', 'DISEASE'), 12),
#  (('reovirus infection', 'DISEASE'), 12),
#  (('brucellosis', 'DISEASE'), 12),
#  (('HLH', 'DISEASE'), 12),
#  (('AIH', 'DISEASE'), 12),
#  (('mitochondrial damage', 'DISEASE'), 12),
#  (('Quercetin', 'CHEMICAL'), 12),
#  (('active infection', 'DISEASE'), 12),
#  (('Ebola Virus Disease', 'DISEASE'), 12),
#  (('aflatoxin', 'CHEMICAL'), 12),
#  (("Parkinson's disease", 'DISEASE'), 12),
#  (('mycetoma infection', 'DISEASE'), 12),
#  (('Fusobacterium', 'CHEMICAL'), 12),
#  ...]
